# %%
import google.generativeai as genai
import PIL.Image
img = PIL.Image.open('image.jpg')

genai.configure(api_key=('YOUR API KEY HERE'))

model = genai.GenerativeModel('gemini-pro-vision')

# %%
import google.generativeai as genai
import PIL.Image
import pprint
img = PIL.Image.open('image1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=277x148>

# %%
model = genai.GenerativeModel('gemini-pro-vision')
response = model.generate_content(img)
answer=response.text
pprint.pprint(answer)
# Out:
# (' The picture shows a group of blue butterflies with one orange butterfly in '
#  'the middle. The orange butterfly stands out because it is different from the '
#  'others. This can be seen as a metaphor for how people can be different from '
#  'each other. The orange butterfly is not afraid to be different, and it '
#  'stands out from the crowd. This is a reminder that people should not be '
#  'afraid to be themselves, even if they are different from others.')
